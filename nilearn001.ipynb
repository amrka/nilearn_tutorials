# %% [markdown]
# # <font color=red> 1. Introduction: nilearn in a nutshell
# </font>

# %%
import nilearn
print(nilearn.__version__)
# Out:
# 0.5.2

# %%
from nilearn import plotting

# %%
ls
# Out:
# Kamalaker.pdf
# VBM_CA3_thresh_40Hz_zstat4.nii.gz
# dr_stage2_subject00007_Z.nii.gz
# dr_stage3_ic0001_tfce_corrp_tstat1.nii.gz
# explore-the-brain-with-nilearn.pdf
# nilearn001.ipynb
# presentation.pdf
# smoothed_img.nii.gz
# volume0.nii.gz

# %%
plotting.plot_glass_brain('dr_stage3_ic0001_tfce_corrp_tstat1.nii.gz')

# %%
from nilearn import image

# %%
smoothed_img = image.smooth_img('dr_stage3_ic0001_tfce_corrp_tstat1.nii.gz', fwhm=5)
print(type(smoothed_img))
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>

# %%
smoothed_img.to_filename('smoothed_image.nii.gz')

# %% [markdown]
# now the image is saved

# %%
index_0 = image.index_img('dr_stage2_subject00007_Z.nii.gz', 0)

# %%
index_0.to_filename('index_0.nii.gz')

# %%
for volume in image.iter_img('dr_stage2_subject00007_Z.nii.gz'):
    print(volume.shape)
    smoothed_img = image.smooth_img(volume, fwhm=5)
# Out:
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)
# (91, 109, 91)

# %% [markdown]
# # excercises

# %%
#download adhd
data = nilearn.datasets.fetch_adhd()
# Out:
# Dataset created in /Users/amr/nilearn_data/adhd
#
# Downloading data from https://www.nitrc.org/frs/download.php/7781/adhd40_metadata.tgz ...
# Downloaded 3072 of 3072 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/74a52d3552145e11365bb68453d1a70c/adhd40_metadata.tgz..... done.
# /Users/amr/anaconda3/lib/python3.7/site-packages/nilearn/datasets/func.py:503: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   dtype=None)
# Downloading data from https://www.nitrc.org/frs/download.php/7782/adhd40_0010042.tgz ...
# Downloaded 44414948 of 44414948 bytes (100.0%,    0.0s remaining) ...done. (7 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0010042.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7783/adhd40_0010064.tgz ...
# Downloaded 45583539 of 45583539 bytes (100.0%,    0.0s remaining) ...done. (7 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0010064.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7784/adhd40_0010128.tgz ...
# Downloaded 45461055 of 45461055 bytes (100.0%,    0.0s remaining) ...done. (16 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0010128.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7785/adhd40_0021019.tgz ...
# Downloaded 46216320 of 46216320 bytes (100.0%,    0.0s remaining) ...done. (8 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0021019.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7786/adhd40_0023008.tgz ...
# Downloaded 20407901 of 20407901 bytes (100.0%,    0.0s remaining) ...done. (9 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0023008.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7787/adhd40_0023012.tgz ...
# Downloaded 20706939 of 20706939 bytes (100.0%,    0.0s remaining) ...done. (6 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_0023012.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7788/adhd40_0027011.tgz ...
# Downloaded 72402326 of 72402326 bytes (100.0%,    0.0s remaining) ...done. (10 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40
tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7811/adhd40_4016887.tgz ...
# Downloaded 20157314 of 20157314 bytes (100.0%,    0.0s remaining) ...done. (5 seconds, 0 min)
# Extracting data from /Users/amr/nilearn_data/adhd/083500922dc983e37a43eed2bafac795/adhd40_4016887.tgz..... done.

# %%
print(data.keys())
print(data.func[0])
# Out:
# dict_keys(['func', 'confounds', 'phenotypic', 'description'])
# /Users/amr/nilearn_data/adhd/data/0010042/0010042_rest_tshift_RPI_voreg_mni.nii.gz

# %%
first_subj = data.func[0]

# %%
avg_1st_subj = image.mean_img(first_subj)

# %%
avg_1st_subj.to_filename('1st_subj_avg.nii.gz')

# %%
for i in range(0,25,5):
    
    print(i)
    smoothed_vol = image.smooth_img(avg_1st_subj, i)
    smoothed_vol.to_filename('1st_subj_avg_smoothed_{0}'.format(i))
    plotting.plot_epi(smoothed_vol)
# Out:
# 0
# 5
# 10
# 15
# 20

# %% [markdown]
# # <font color=red>8.1.2. Basic nilearn example: manipulating and looking at data
#
# </font>

# %%
from nilearn.datasets import MNI152_FILE_PATH

# %%
MNI152_FILE_PATH
# Out:
# '/Users/amr/anaconda3/lib/python3.7/site-packages/nilearn/datasets/data/avg152T1_brain.nii.gz'

# %%
print('Path to MNI152 template: {0}'.format(MNI152_FILE_PATH))
# Out:
# Path to MNI152 template: /Users/amr/anaconda3/lib/python3.7/site-packages/nilearn/datasets/data/avg152T1_brain.nii.gz

# %%
plotting.plot_img(MNI152_FILE_PATH)

# %% [markdown]
# Functions containing ‘img’ can take either a filename or an image as input.
#
# e.g smooth_img

# %%
from nilearn import image

# %%
smooth_anat_img = image.smooth_img(MNI152_FILE_PATH, fwhm=3)

# %%
plotting.plot_anat(smooth_anat_img)

# %%
#to get the header
smooth_anat_img??
# or
print(smooth_anat_img)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (91, 109, 91)
# affine:
# [[  -2.    0.    0.   90.]
#  [   0.    2.    0. -126.]
#  [   0.    0.    2.  -72.]
#  [   0.    0.    0.    1.]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3  91 109  91   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.  2.  2.  2.  1.  1.  1.  1.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 8274.68
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'FSL3.3'
# aux_file        : b''
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 90.0
# qoffset_y       : -126.0
# qoffset_z       : -72.0
# srow_x          : [-2.  0.  0. 90.]
# srow_y          : [   0.    2.    0. -126.]
# srow_z          : [  0.   0.   2. -72.]
# intent_name     : b''
# magic           : b'n+1'

# %%
more_smooth_anat_img = image.smooth_img(smooth_anat_img, fwhm=3)

# %%
plotting.plot_anat(more_smooth_anat_img)

# %% [markdown]
# # <font color=red>8.1.3. 3D and 4D niimgs: handling and visualizing</font>

# %%
from nilearn import datasets

print('Datasets are stored in:{0}'.format(datasets.get_data_dirs()))
# Out:
# Datasets are stored in:['/Users/amr/nilearn_data']

# %%
motor_images = datasets.fetch_neurovault_motor_task()
print(motor_images.images)
# Out:
# Dataset created in /Users/amr/nilearn_data/neurovault
#
# ['/Users/amr/nilearn_data/neurovault/collection_658/image_10426.nii.gz']

# %%
type(motor_images.images)
# Out:
# list

# %%
#you cannot plot a list, that's why you need the single file
tmap_filename = motor_images.images[0]

# %%
plotting.plot_stat_map(tmap_filename)

# %%
# !cp /Users/amr/nilearn_data/neurovault/collection_658/image_10426.nii.gz .

# %%
plotting.plot_stat_map(tmap_filename, threshold=3)

# %%
plotting.plot_stat_map(tmap_filename, threshold=0)

# %% [markdown]
# ## visualize 4D

# %%
rsn = datasets.fetch_atlas_smith_2009()['rsn10']
# Out:
# Dataset created in /Users/amr/nilearn_data/smith_2009
#
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/rsn20.nii.gz ...
# Downloaded 15129514 of 15129514 bytes (100.0%,    0.0s remaining) ...done. (2 seconds, 0 min)
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/PNAS_Smith09_rsn10.nii.gz ...
# Downloaded 7565016 of 7565016 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/rsn70.nii.gz ...
# Downloaded 53028809 of 53028809 bytes (100.0%,    0.0s remaining) ...done. (3 seconds, 0 min)
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/bm20.nii.gz ...
# Downloaded 19114114 of 19114114 bytes (100.0%,    0.0s remaining) ...done. (4 seconds, 0 min)
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/PNAS_Smith09_bm10.nii.gz ...
# Downloaded 9566632 of 9566632 bytes (100.0%,    0.0s remaining) ...done. (2 seconds, 0 min)
# Downloading data from http://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/bm70.nii.gz ...
# Downloaded 67017538 of 67017538 bytes (100.0%,    0.0s remaining) ...done. (4 seconds, 0 min)

# %%
print(rsn)
print(type(rsn))
#a 4d map with 10 ICs
# Out:
# /Users/amr/nilearn_data/smith_2009/PNAS_Smith09_rsn10.nii.gz
# <class 'str'>

# %%
# !fsleyes /Users/amr/nilearn_data/smith_2009/PNAS_Smith09_rsn10.nii.gz
# Out:
# /bin/sh: {fsleyes: command not found

# %%
print(image.load_img(rsn).shape)
# Out:
# (91, 109, 91, 10)

# %%
first_rsn = image.index_img(rsn, 0)

# %%
type(first_rsn)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
plotting.plot_stat_map(first_rsn, threshold=1)

# %%
for img in image.iter_img(rsn):
    plotting.plot_stat_map(img, threshold=3, display_mode='z', cut_coords=1,colorbar=False)
# Out:
# /Users/amr/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
import numpy as np

# %%
t = np.linspace(1, 10, 2000)

# %%
np.cos(t)
# Out:
# array([ 0.54030231,  0.53650833,  0.53270348, ..., -0.84393609,
#        -0.84151234, -0.83907153])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t, np.cos(t))

# %%
from scipy import ndimage
t_smooth = ndimage.gaussian_filter(t, sigma=2)

# %%
from scipy import signal
t_detrended = signal.detrend(t)

# %%
plt.plot(np.cos(t_detrended))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.20.1
